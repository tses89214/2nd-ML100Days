# %% [markdown]
# # 作業1

# %% [markdown]
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# 我所選擇的是來自Instacart Market Basket Analysis的資料，Instacart是一個提供下訂單跟運送的APP，用戶在下訂單後購買雜貨後，會有專人送到用戶家中。
#
# 1. 你選的這組資料為何重要
# 我本身對於消費者行為就是有興趣的，關聯分析更是眾多大數據應用的例子裡最常被提及的。所以我選擇的原因是因為我覺得他好玩。當然對於企業的應用也很有幫助，像是預測訂購數量及用戶位置便可以提供更快速的服務。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 資料來自於上述的訂單資料，以及該APP本身的用戶資料。還有商品在商場的走道或區域的資料。以及整理出了商品是否被再次購買等資料。
#
# 3. 蒐集而來的資料型態為何
# 是結構化的購買資料(數值)。
#
# 4. 這組資料想解決的問題如何評估
# 在該場比賽中是使用Mean F1 Score來做評估，根據網路上查到的資料，F1 Score算是一個評估預測率及正確率的綜合指標，常用在此種預測是/否的情境下。此外也可以透過混淆矩陣來計算其他例如precision，recall等指標。

# %% [markdown]
# # 作業2

# %% [markdown]
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 提升業績亦即某位司機所載的乘客數量是更多的，以及司機花更少的時間在搜尋客戶、待機或移動到指定地點接客人。因此這邊也假設司機遇到的問題是：不知道客戶在哪裡以及因為不知道客戶需求量大小，花太多時間在移動(例如因為人手不足必須從某A點跑到非常遠方的B點去載客)。因此我認為只要能夠預測每個時間點及地點的客戶需求量，就可以分配足夠的人手，也讓需求跟供給互相滿足。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 我認為可以從車隊的載客紀錄分析，可能包含每個時間點，在哪個地點、載了多少客人，載了多遠、哪裡下車，我認為該紀錄主要的資料來源為司機自主紀錄及回報即可。
#
# 3. 蒐集而來的資料型態為何
# 資料型態應該是結構化資料，並且包含文字(地點)、時間、跟數值(距離及人數)。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 我認為可以從司機的平均待機時間、接到客人前平均移動時間以及客人的平均等待時間來評估(表示該地點的需求跟供給越match)。在實施這個措施之後兩者應該都會顯著下降。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(Y,Y_hat):
    return(sum((Y-Y_hat)**2)/len(Y))
    
def mean_absolute_error(Y,Y_hat):
    return(sum((abs(Y-Y_hat)))/len(Y))

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 243.613
# The Mean absolute error is 12.995

# %% [markdown]
# ## Work
# 1. 請自行定義一個 loss function, 為 0.3 * focal loss + 0.7 cross-entropy，訓練並比較結果

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization,Dropout
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    """Code Here
    建立你的神經網路
    """
    
    input_layer  = keras.layers.Input(input_shape)
    
    for i , num in enumerate(num_neurons):
        if i ==0:
            x = keras.layers.Dense(units = num,activation='relu',name='HIDDEN_LAYER_'+str(i+1))(input_layer)
            x = BatchNormalization()(x)
            x  = Dropout(0.1)(x)
        else:
            x = keras.layers.Dense(units = num,activation='relu',name='HIDDEN_LAYER_'+str(i+1))(x)
            x = BatchNormalization()(x)
            x  = Dropout(0.1)(x)
            
    out = keras.layers.Dense(units=output_units,activation='softmax',name="OUTPUT_LAYER")(x)   
    
    model = keras.models.Model(inputs=[input_layer],outputs=[out])
    
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
import tensorflow as tf
import keras.backend as K

"""Code Here
撰寫一個 loss function, 使其可以結合 focal loss 與 crossentropy loss
"""
def combined_loss(gamma=2., alpha=4.,ce_w = 0.7):
    """Define the customized loss."""
    gamma = float(gamma)
    alpha = float(alpha)
    def focal_loss_fixed(y_true, y_pred):
        """Focal loss for multi-classification
        FL(p_t)=-alpha(1-p_t)^{gamma}ln(p_t)
        """
        epsilon = 1e-8
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)

        model_out = tf.add(y_pred, epsilon)
        ce = tf.multiply(y_true, -tf.log(model_out))
        weight = tf.multiply(y_true, tf.pow(tf.subtract(1., model_out), gamma))
        fl = tf.multiply(alpha, tf.multiply(weight, ce))
        reduced_fl = tf.reduce_max(fl, axis=1)
        
        focal_loss_fixed = tf.reduce_mean(reduced_fl)
        mixed = tf.nn.sigmoid_cross_entropy_with_logits(labels=y_true,logits=y_pred)*ce_w + focal_loss_fixed*(1-ce_w)
        
        return mixed
    
#     mixed = tf.nn.sigmoid_cross_entropy_with_logits(labels=y_true,logits=y_pred)*ce_w + focal_loss_fixed*(1-ce_w)
    
    return focal_loss_fixed

ce_weights_list = [0., 0.3, 0.5, 0.7, 1]

# %%
import itertools
results = {}

for i, ce_w in enumerate(ce_weights_list):
    print("Numbers of exp: %i, ce_weight: %.2f" % (i, ce_w))

    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    """Code Here
    將自定義的 loss function 加入模型
    """
    model.compile(loss=combined_loss(ce_w = ce_w), metrics=["accuracy"], optimizer=optimizer)
    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True
             )
    
    # Collect results
    exp_name_tag = ("exp-%s" % (i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["acc"],
                             'valid-acc': model.history.history["val_acc"]}
# Out:
# Numbers of exp: 0, ce_weight: 0.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# HIDDEN_LAYER_1 (Dense)       (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# HIDDEN_LAYER_2 (Dense)       (None, 256)               131328
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# HIDDEN_LAYER_3 (Dense)       (None, 128)               32896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# OUTPUT_LAYER (Dense)         (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\Xuan\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\Xuan\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 5s 109us/step - loss: 6.7086 - acc: 0.2886 - val_loss: 5.9200 - val_acc: 0.3452
# Epoch 2/25
# 50000/50000 [==============================] - 3s 59us/step - loss: 4.9911 - acc: 0.3809 - val_loss: 4.7635 - val_acc: 0.4056
# Epoch 3/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 4.5664 - acc: 0.4192 - val_loss: 4.4052 - val_acc: 0.4323
# Epoch 4/25
# 50000/50000 [==============================] - 3s 64us/step - loss: 4.3268 - acc: 0.4403 - val_loss: 4.2325 - val_acc: 0.4478
# Epoch 5/25
# 50000/50000 [==============================] - 3s 65us/step - loss: 4.1115 - acc: 0.4585 - val_loss: 4.1000 - val_acc: 0.4594
# Epoch 6/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 3.9859 - acc: 0.4711 - val_loss: 4.0906 - val_acc: 0.4651
# Epoch 7/25
# 50000/50000 [==============================] - 3s 67us/step - loss: 3.8654 - acc: 0.4843 - val_loss: 4.0275 - val_acc: 0.4655
# Epoch 8/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 3.7354 - acc: 0.4960 - val_loss: 3.9669 - val_acc: 0.4788
# Epoch 9/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 3.6580 - acc: 0.5006 - val_loss: 3.8850 - val_acc: 0.4802
# Epoch 10/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 3.5561 - acc: 0.5108 - val_loss: 3.8802 - val_acc: 0.4806
# Epoch 11/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 3.4949 - acc: 0.5168 - val_loss: 3.8394 - val_acc: 0.4817
# Epoch 12/25
# 50000/50000 [==============================] - 3s 59us/step - loss: 3.4201 - acc: 0.5257 - val_loss: 3.7199 - val_acc: 0.4985
# Epoch 13/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 3.3507 - acc: 0.5322 - val_loss: 3.9307 - val_acc: 0.4843
# Epoch 14/25
# 50000/50000 [==============================] - 2s 49us/step - loss: 3.2893 - acc: 0.5359 - val_loss: 3.6405 - val_acc: 0.5047
# Epoch 15/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 3.2270 - acc: 0.5424 - val_loss: 3.6960 - val_acc: 0.4977
# Epoch 16/25
# 50000/50000 [==============================] - 2s 50us/step - loss: 3.1733 - acc: 0.5477 - val_loss: 3.6220 - val_acc: 0.5079
# Epoch 17/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 3.1384 - acc: 0.5535 - val_loss: 3.6427 - val_acc: 0.5062
# Epoch 18/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 3.0773 - acc: 0.5559 - val_loss: 3.5439 - val_acc: 0.5202
# Epoch 19/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 3.0148 - acc: 0.5620 - val_loss: 3.5525 - val_acc: 0.5200
# Epoch 20/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.9708 - acc: 0.5657 - val_loss: 3.5604 - val_acc: 0.5125
# Epoch 21/25
# 50000/50000 [==============================] - 3s 66us/step - loss: 2.9327 - acc: 0.5723 - val_loss: 3.5066 - val_acc: 0.5172
# Epoch 22/25
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.8879 - acc: 0.5736 - val_loss: 3.7597 - val_acc: 0.4998
# Epoch 23/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 2.8247 - acc: 0.5818 - val_loss: 3.4962 - val_acc: 0.5222
# Epoch 24/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 2.7938 - acc: 0.5835 - val_loss: 3.5332 - val_acc: 0.5147
# Epoch 25/25
# 50000/50000 [==============================] - 3s 61us/step - loss: 2.7589 - acc: 0.5856 - val_loss: 3.5776 - val_acc: 0.5174
# Numbers of exp: 1, ce_weight: 0.30
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# HIDDEN_LAYER_1 (Dense)       (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# HIDDEN_LAYER_2 (Dense)       (None, 256)               131328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# HIDDEN_LAYER_3 (Dense)       (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# OUTPUT_LAYER (Dense)         (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 4s 79us/step - loss: 5.2190 - acc: 0.2795 - val_loss: 4.8498 - val_acc: 0.3352
# Epoch 2/25
# 50000/50000 [==============================] - 3s 60us/step - loss: 3.8821 - acc: 0.3735 - val_loss: 3.6833 - val_acc: 0.4041
# Epoch 3/25
# 50000/50000 [==============================] - 3s 59us/step - loss: 3.5505 - acc: 0.4088 - val_loss: 3.4392 - val_acc: 0.4224
# Epoch 4/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 3.3566 - acc: 0.4298 - val_loss: 3.2860 - val_acc: 0.4399
# Epoch 5/25
# 50000/50000 [==============================] - 3s 59us/step - loss: 3.2240 - acc: 0.4471 - val_loss: 3.2550 - val_acc: 0.4497
# Epoch 6/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 3.1161 - acc: 0.4596 - val_loss: 3.1928 - val_acc: 0.4490
# Epoch 7/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 3.0274 - acc: 0.4710 - val_loss: 3.0668 - val_acc: 0.4671
# Epoch 8/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.9493 - acc: 0.4835 - val_loss: 3.0758 - val_acc: 0.4663
# Epoch 9/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.8798 - acc: 0.4910 - val_loss: 2.9637 - val_acc: 0.4810
# Epoch 10/25
# 50000/50000 [==============================] - 2s 49us/step - loss: 2.8222 - acc: 0.5003 - val_loss: 2.9368 - val_acc: 0.4840
# Epoch 11/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.7591 - acc: 0.5053 - val_loss: 2.9396 - val_acc: 0.4761
# Epoch 12/25
# 50000/50000 [==============================] - 3s 59us/step - loss: 2.7080 - acc: 0.5152 - val_loss: 2.9242 - val_acc: 0.4894
# Epoch 13/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.6518 - acc: 0.5191 - val_loss: 2.8606 - val_acc: 0.4973
# Epoch 14/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 2.6113 - acc: 0.5261 - val_loss: 2.7835 - val_acc: 0.5078
# Epoch 15/25
# 50000/50000 [==============================] - 2s 50us/step - loss: 2.5612 - acc: 0.5336 - val_loss: 2.7868 - val_acc: 0.5054
# Epoch 16/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.5241 - acc: 0.5359 - val_loss: 2.8051 - val_acc: 0.4992
# Epoch 17/25
# 50000/50000 [==============================] - 3s 61us/step - loss: 2.4728 - acc: 0.5464 - val_loss: 2.7551 - val_acc: 0.5078
# Epoch 18/25
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.4620 - acc: 0.5469 - val_loss: 2.7856 - val_acc: 0.5070
# Epoch 19/25
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.4213 - acc: 0.5535 - val_loss: 2.7678 - val_acc: 0.5046
# Epoch 20/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3816 - acc: 0.5589 - val_loss: 2.7207 - val_acc: 0.5136
# Epoch 21/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 2.3418 - acc: 0.5643 - val_loss: 2.7291 - val_acc: 0.5114
# Epoch 22/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.3116 - acc: 0.5707 - val_loss: 2.7243 - val_acc: 0.5109
# Epoch 23/25
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.2748 - acc: 0.5745 - val_loss: 2.7559 - val_acc: 0.5033
# Epoch 24/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 2.2568 - acc: 0.5761 - val_loss: 2.7578 - val_acc: 0.5090
# Epoch 25/25
# 50000/50000 [==============================] - 3s 67us/step - loss: 2.2230 - acc: 0.5811 - val_loss: 2.7160 - val_acc: 0.5123
# Numbers of exp: 2, ce_weight: 0.50
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# HIDDEN_LAYER_1 (Dense)       (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# HIDDEN_LAYER_2 (Dense)       (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# HIDDEN_LAYER_3 (Dense)       (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 128)               0
# _________________________________________________________________
# OUTPUT_LAYER (Dense)         (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 4.0482 - acc: 0.2648 - val_loss: 3.8927 - val_acc: 0.2959
# Epoch 2/25
# 50000/50000 [==============================] - 3s 56us/step - loss: 3.0607 - acc: 0.3630 - val_loss: 2.8940 - val_acc: 0.3926
# Epoch 3/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.8092 - acc: 0.3976 - val_loss: 2.7565 - val_acc: 0.3951
# Epoch 4/25
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.6830 - acc: 0.4189 - val_loss: 2.5992 - val_acc: 0.4284
# Epoch 5/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 2.5743 - acc: 0.4348 - val_loss: 2.5312 - val_acc: 0.4400
# Epoch 6/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.4961 - acc: 0.4520 - val_loss: 2.4737 - val_acc: 0.4473
# Epoch 7/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 2.4388 - acc: 0.4587 - val_loss: 2.4630 - val_acc: 0.4494
# Epoch 8/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.3818 - acc: 0.4679 - val_loss: 2.4122 - val_acc: 0.4570
# Epoch 9/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.3396 - acc: 0.4768 - val_loss: 2.3566 - val_acc: 0.4717
# Epoch 10/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 2.2873 - acc: 0.4856 - val_loss: 2.3289 - val_acc: 0.4807
# Epoch 11/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 2.2503 - acc: 0.4952 - val_loss: 2.3083 - val_acc: 0.4840
# Epoch 12/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 2.2114 - acc: 0.4998 - val_loss: 2.2937 - val_acc: 0.4837
# Epoch 13/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.1778 - acc: 0.5078 - val_loss: 2.2589 - val_acc: 0.4924
# Epoch 14/25
# 50000/50000 [==============================] - 3s 56us/step - loss: 2.1550 - acc: 0.5108 - val_loss: 2.2334 - val_acc: 0.5002
# Epoch 15/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 2.1225 - acc: 0.5166 - val_loss: 2.2607 - val_acc: 0.4911
# Epoch 16/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 2.0922 - acc: 0.5219 - val_loss: 2.2194 - val_acc: 0.4963
# Epoch 17/25
# 50000/50000 [==============================] - 3s 56us/step - loss: 2.0698 - acc: 0.5274 - val_loss: 2.2251 - val_acc: 0.4942
# Epoch 18/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.0458 - acc: 0.5321 - val_loss: 2.1839 - val_acc: 0.5065
# Epoch 19/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.0193 - acc: 0.5363 - val_loss: 2.1927 - val_acc: 0.5090
# Epoch 20/25
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.9964 - acc: 0.5416 - val_loss: 2.1973 - val_acc: 0.5087
# Epoch 21/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 1.9766 - acc: 0.5472 - val_loss: 2.1788 - val_acc: 0.5124
# Epoch 22/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.9517 - acc: 0.5520 - val_loss: 2.1983 - val_acc: 0.5062
# Epoch 23/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.9252 - acc: 0.5550 - val_loss: 2.1761 - val_acc: 0.5056
# Epoch 24/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.9089 - acc: 0.5581 - val_loss: 2.1491 - val_acc: 0.5145
# Epoch 25/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.8846 - acc: 0.5650 - val_loss: 2.1258 - val_acc: 0.5179
# Numbers of exp: 3, ce_weight: 0.70
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# HIDDEN_LAYER_1 (Dense)       (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# HIDDEN_LAYER_2 (Dense)       (None, 256)               131328
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# HIDDEN_LAYER_3 (Dense)       (None, 128)               32896
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 128)               0
# _________________________________________________________________
# OUTPUT_LAYER (Dense)         (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 4s 80us/step - loss: 2.8658 - acc: 0.2441 - val_loss: 2.4425 - val_acc: 0.3223
# Epoch 2/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.2401 - acc: 0.3430 - val_loss: 2.1372 - val_acc: 0.3668
# Epoch 3/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 2.0670 - acc: 0.3780 - val_loss: 2.0049 - val_acc: 0.3988
# Epoch 4/25
# 50000/50000 [==============================] - 3s 65us/step - loss: 1.9828 - acc: 0.3977 - val_loss: 1.8851 - val_acc: 0.4198
# Epoch 5/25
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.9199 - acc: 0.4134 - val_loss: 1.8456 - val_acc: 0.4336
# Epoch 6/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.8651 - acc: 0.4271 - val_loss: 1.8502 - val_acc: 0.4262
# Epoch 7/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.8271 - acc: 0.4388 - val_loss: 1.7989 - val_acc: 0.4448
# Epoch 8/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.7929 - acc: 0.4529 - val_loss: 1.7685 - val_acc: 0.4580
# Epoch 9/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.7586 - acc: 0.4582 - val_loss: 1.7706 - val_acc: 0.4530
# Epoch 10/25
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.7376 - acc: 0.4618 - val_loss: 1.7332 - val_acc: 0.4668
# Epoch 11/25
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.7124 - acc: 0.4706 - val_loss: 1.7198 - val_acc: 0.4652
# Epoch 12/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.6923 - acc: 0.4778 - val_loss: 1.7044 - val_acc: 0.4826
# Epoch 13/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.6676 - acc: 0.4849 - val_loss: 1.6996 - val_acc: 0.4771
# Epoch 14/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.6550 - acc: 0.4845 - val_loss: 1.6801 - val_acc: 0.4830
# Epoch 15/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.6259 - acc: 0.4980 - val_loss: 1.6807 - val_acc: 0.4855
# Epoch 16/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.6150 - acc: 0.4998 - val_loss: 1.6609 - val_acc: 0.4975
# Epoch 17/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.5986 - acc: 0.5041 - val_loss: 1.6623 - val_acc: 0.4879
# Epoch 18/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.5834 - acc: 0.5095 - val_loss: 1.6453 - val_acc: 0.4926
# Epoch 19/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.5702 - acc: 0.5107 - val_loss: 1.6385 - val_acc: 0.4989
# Epoch 20/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.5497 - acc: 0.5214 - val_loss: 1.6398 - val_acc: 0.5035
# Epoch 21/25
# 50000/50000 [==============================] - 2s 49us/step - loss: 1.5423 - acc: 0.5228 - val_loss: 1.6314 - val_acc: 0.4997
# Epoch 22/25
# 50000/50000 [==============================] - 2s 49us/step - loss: 1.5288 - acc: 0.5248 - val_loss: 1.6291 - val_acc: 0.4956
# Epoch 23/25
# 50000/50000 [==============================] - 2s 49us/step - loss: 1.5135 - acc: 0.5307 - val_loss: 1.6554 - val_acc: 0.4886
# Epoch 24/25
# 50000/50000 [==============================] - 2s 49us/step - loss: 1.5015 - acc: 0.5378 - val_loss: 1.6136 - val_acc: 0.4998
# Epoch 25/25
# 50000/50000 [==============================] - 2s 50us/step - loss: 1.4882 - acc: 0.5407 - val_loss: 1.6242 - val_acc: 0.4982
# Numbers of exp: 4, ce_weight: 1.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# HIDDEN_LAYER_1 (Dense)       (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 512)               0
# _________________________________________________________________
# HIDDEN_LAYER_2 (Dense)       (None, 256)               131328
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# HIDDEN_LAYER_3 (Dense)       (None, 128)               32896
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 128)               0
# _________________________________________________________________
# OUTPUT_LAYER (Dense)         (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.7355 - acc: 0.1155 - val_loss: 0.7343 - val_acc: 0.1320
# Epoch 2/25
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.7345 - acc: 0.1326 - val_loss: 0.7326 - val_acc: 0.1659
# Epoch 3/25
# 50000/50000 [==============================] - 2s 50us/step - loss: 0.7332 - acc: 0.1575 - val_loss: 0.7312 - val_acc: 0.1850
# Epoch 4/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.7320 - acc: 0.1757 - val_loss: 0.7301 - val_acc: 0.2022
# Epoch 5/25
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.7309 - acc: 0.1946 - val_loss: 0.7290 - val_acc: 0.2188
# Epoch 6/25
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.7298 - acc: 0.2097 - val_loss: 0.7281 - val_acc: 0.2297
# Epoch 7/25
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.7290 - acc: 0.2202 - val_loss: 0.7273 - val_acc: 0.2425
# Epoch 8/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.7284 - acc: 0.2284 - val_loss: 0.7266 - val_acc: 0.2522
# Epoch 9/25
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.7276 - acc: 0.2399 - val_loss: 0.7260 - val_acc: 0.2592
# Epoch 10/25
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.7271 - acc: 0.2476 - val_loss: 0.7254 - val_acc: 0.2659
# Epoch 11/25
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.7264 - acc: 0.2581 - val_loss: 0.7250 - val_acc: 0.2733
# Epoch 12/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 0.7259 - acc: 0.2632 - val_loss: 0.7246 - val_acc: 0.2771
# Epoch 13/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 0.7254 - acc: 0.2710 - val_loss: 0.7242 - val_acc: 0.2824
# Epoch 14/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.7251 - acc: 0.2732 - val_loss: 0.7239 - val_acc: 0.2866
# Epoch 15/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 0.7247 - acc: 0.2787 - val_loss: 0.7236 - val_acc: 0.2911
# Epoch 16/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.7243 - acc: 0.2850 - val_loss: 0.7232 - val_acc: 0.2965
# Epoch 17/25
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.7241 - acc: 0.2869 - val_loss: 0.7230 - val_acc: 0.3010
# Epoch 18/25
# 50000/50000 [==============================] - 4s 71us/step - loss: 0.7237 - acc: 0.2929 - val_loss: 0.7227 - val_acc: 0.3059
# Epoch 19/25
# 50000/50000 [==============================] - 4s 73us/step - loss: 0.7235 - acc: 0.2955 - val_loss: 0.7224 - val_acc: 0.3106
# Epoch 20/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 0.7232 - acc: 0.3001 - val_loss: 0.7222 - val_acc: 0.3132
# Epoch 21/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.7230 - acc: 0.3027 - val_loss: 0.7219 - val_acc: 0.3170
# Epoch 22/25
# 50000/50000 [==============================] - 3s 53us/step - loss: 0.7226 - acc: 0.3095 - val_loss: 0.7217 - val_acc: 0.3198
# Epoch 23/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.7225 - acc: 0.3092 - val_loss: 0.7214 - val_acc: 0.3231
# Epoch 24/25
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.7221 - acc: 0.3144 - val_loss: 0.7212 - val_acc: 0.3277
# Epoch 25/25
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.7219 - acc: 0.3164 - val_loss: 0.7210 - val_acc: 0.3290

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = len(results.keys())

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

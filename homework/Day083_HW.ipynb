# %% [markdown]
# ## Work
# 1. 試比較有 BN 在 Batch_size = 2, 16, 32, 128, 256 下的差異
# 2. 請嘗試將 BN 放在 Activation 之前，並比較訓練結果
# 3. 請於 BN 放在 Input Layer 後，並比較結果

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = [128,256,512]
MOMENTUM = 0.95

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
for bs in BATCH_SIZE:
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=bs, 
          validation_data=(x_test, y_test), 
          shuffle=True)

    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["acc"]
    valid_acc = model.history.history["val_acc"]
    
    results[str(bs)] = {
        'train_loss' : train_loss,
        'valid_loss':valid_loss,
        'train_acc':train_acc,
        'valid_acc':valid_acc
    }
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.7536 - acc: 0.3888 - val_loss: 1.6440 - val_acc: 0.4195
# Epoch 2/50
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.4896 - acc: 0.4765 - val_loss: 1.5594 - val_acc: 0.4427
# Epoch 3/50
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.3907 - acc: 0.5078 - val_loss: 1.5692 - val_acc: 0.4453
# Epoch 4/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.3218 - acc: 0.5313 - val_loss: 1.4973 - val_acc: 0.4739
# Epoch 5/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.2614 - acc: 0.5551 - val_loss: 1.5355 - val_acc: 0.4587
# Epoch 6/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.2113 - acc: 0.5735 - val_loss: 1.4704 - val_acc: 0.4721
# Epoch 7/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.1666 - acc: 0.5881 - val_loss: 1.4877 - val_acc: 0.4730
# Epoch 8/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.1247 - acc: 0.6025 - val_loss: 1.4845 - val_acc: 0.4760
# Epoch 9/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.0803 - acc: 0.6197 - val_loss: 1.5313 - val_acc: 0.4710
# Epoch 10/50
# 50000/50000 [==============================] - 6s 116us/step - loss: 1.0448 - acc: 0.6334 - val_loss: 1.4791 - val_acc: 0.4867
# Epoch 11/50
# 50000/50000 [==============================] - 7s 138us/step - loss: 1.0163 - acc: 0.6449 - val_loss: 1.5965 - val_acc: 0.4623
# Epoch 12/50
# 50000/50000 [==============================] - 7s 130us/step - loss: 0.9836 - acc: 0.6547 - val_loss: 1.5402 - val_acc: 0.4780
# Epoch 13/50
# 50000/50000 [==============================] - 6s 119us/step - loss: 0.9504 - acc: 0.6667 - val_loss: 1.6484 - val_acc: 0.4679
# Epoch 14/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 0.9321 - acc: 0.6723 - val_loss: 1.6305 - val_acc: 0.4604
# Epoch 15/50
# 50000/50000 [==============================] - 6s 128us/step - loss: 0.9024 - acc: 0.6826 - val_loss: 1.6498 - val_acc: 0.4541
# Epoch 16/50
# 50000/50000 [==============================] - 6s 127us/step - loss: 0.8617 - acc: 0.6990 - val_loss: 1.5606 - val_acc: 0.4888
# Epoch 17/50
# 50000/50000 [==============================] - 6s 119us/step - loss: 0.8280 - acc: 0.7092 - val_loss: 1.7109 - val_acc: 0.4560
# Epoch 18/50
# 50000/50000 [==============================] - 6s 120us/step - loss: 0.8074 - acc: 0.7165 - val_loss: 1.6566 - val_acc: 0.4682
# Epoch 19/50
# 50000/50000 [==============================] - 6s 121us/step - loss: 0.7728 - acc: 0.7309 - val_loss: 1.6912 - val_acc: 0.4699
# Epoch 20/50
# 50000/50000 [==============================] - 6s 121us/step - loss: 0.7543 - acc: 0.7367 - val_loss: 1.7802 - val_acc: 0.4653
# Epoch 21/50
# 50000/50000 [==============================] - 6s 120us/step - loss: 0.7228 - acc: 0.7475 - val_loss: 1.6401 - val_acc: 0.4808
# Epoch 22/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.6964 - acc: 0.7575 - val_loss: 1.7340 - val_acc: 0.4789
# Epoch 23/50
# 50000/50000 [==============================] - 7s 139us/step - loss: 0.6692 - acc: 0.7677 - val_loss: 1.7473 - val_acc: 0.4693
# Epoch 24/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.6514 - acc: 0.7730 - val_loss: 1.9597 - val_acc: 0.4412
# Epoch 25/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 0.6167 - acc: 0.7872 - val_loss: 1.7694 - val_acc: 0.4771
# Epoch 26/50
# 50000/50000 [==============================] - 6s 121us/step - loss: 0.5972 - acc: 0.7927 - val_loss: 1.8297 - val_acc: 0.4723
# Epoch 27/50
# 50000/50000 [==============================] - 6s 121us/step - loss: 0.5729 - acc: 0.8029 - val_loss: 1.8911 - val_acc: 0.4634
# Epoch 28/50
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.5562 - acc: 0.8082 - val_loss: 2.0073 - val_acc: 0.4512
# Epoch 29/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 0.5384 - acc: 0.8130 - val_loss: 1.9418 - val_acc: 0.4600
# Epoch 30/50
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.5230 - acc: 0.8201 - val_loss: 1.8896 - val_acc: 0.4837
# Epoch 31/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.5017 - acc: 0.8263 - val_loss: 1.8982 - val_acc: 0.4796
# Epoch 32/50
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.4841 - acc: 0.8328 - val_loss: 1.9722 - val_acc: 0.4580
# Epoch 33/50
# 50000/50000 [==============================] - 6s 125us/step - loss: 0.4632 - acc: 0.8401 - val_loss: 2.1961 - val_acc: 0.4390
# Epoch 34/50
# 50000/50000 [==============================] - 6s 125us/step - loss: 0.4458 - acc: 0.8462 - val_loss: 2.1546 - val_acc: 0.4584
# Epoch 35/50
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.4350 - acc: 0.8492 - val_loss: 2.2122 - val_acc: 0.4473
# Epoch 36/50
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.4275 - acc: 0.8511 - val_loss: 2.2698 - val_acc: 0.4444
# Epoch 37/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 0.4145 - acc: 0.8562 - val_loss: 2.1508 - val_acc: 0.4527
# Epoch 38/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 0.3923 - acc: 0.8654 - val_loss: 2.2398 - val_acc: 0.4654
# Epoch 39/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.3788 - acc: 0.8702 - val_loss: 2.1584 - val_acc: 0.4716
# Epoch 40/50
# 50000/50000 [==============================] - 5s 91us/step - loss: 0.3592 - acc: 0.8764 - val_loss: 2.1586 - val_acc: 0.4645
# Epoch 41/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.3433 - acc: 0.8823 - val_loss: 2.3429 - val_acc: 0.4545
# Epoch 42/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.3393 - acc: 0.8841 - val_loss: 2.3590 - val_acc: 0.4543
# Epoch 43/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.3359 - acc: 0.8847 - val_loss: 2.4624 - val_acc: 0.4548
# Epoch 44/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.3203 - acc: 0.8904 - val_loss: 2.2614 - val_acc: 0.4668
# Epoch 45/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.3094 - acc: 0.8938 - val_loss: 2.4675 - val_acc: 0.4674
# Epoch 46/50
# 50000/50000 [==============================] - 4s 86us/step - loss: 0.3006 - acc: 0.8966 - val_loss: 2.2467 - val_acc: 0.4786
# Epoch 47/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.2854 - acc: 0.9031 - val_loss: 2.6616 - val_acc: 0.4551
# Epoch 48/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.2773 - acc: 0.9061 - val_loss: 2.3578 - val_acc: 0.4650
# Epoch 49/50
# 50000/50000 [==============================] - 5s 91us/step - loss: 0.2605 - acc: 0.9129 - val_loss: 2.3921 - val_acc: 0.4682
# Epoch 50/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.2516 - acc: 0.9145 - val_loss: 2.6920 - val_acc: 0.4538
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 1.8456 - acc: 0.3622 - val_loss: 1.7395 - val_acc: 0.3957
# Epoch 2/50
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.5402 - acc: 0.4583 - val_loss: 1.6061 - val_acc: 0.4306
# Epoch 3/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 1.4388 - acc: 0.4939 - val_loss: 1.5613 - val_acc: 0.4533
# Epoch 4/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 1.3665 - acc: 0.5200 - val_loss: 1.5300 - val_acc: 0.4663
# Epoch 5/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.3061 - acc: 0.5452 - val_loss: 1.5240 - val_acc: 0.4604
# Epoch 6/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.2570 - acc: 0.5614 - val_loss: 1.5128 - val_acc: 0.4625
# Epoch 7/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.2121 - acc: 0.5753 - val_loss: 1.5802 - val_acc: 0.4593
# Epoch 8/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.1623 - acc: 0.5956 - val_loss: 1.4558 - val_acc: 0.4938
# Epoch 9/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.1235 - acc: 0.6098 - val_loss: 1.4708 - val_acc: 0.4876
# Epoch 10/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.0860 - acc: 0.6208 - val_loss: 1.4447 - val_acc: 0.4965
# Epoch 11/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.0516 - acc: 0.6353 - val_loss: 1.5049 - val_acc: 0.4792
# Epoch 12/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.0168 - acc: 0.6470 - val_loss: 1.5127 - val_acc: 0.4807
# Epoch 13/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.9846 - acc: 0.6581 - val_loss: 1.4814 - val_acc: 0.4907
# Epoch 14/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.9507 - acc: 0.6717 - val_loss: 1.5197 - val_acc: 0.4905
# Epoch 15/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.9145 - acc: 0.6848 - val_loss: 1.5258 - val_acc: 0.4889
# Epoch 16/50
# 50000/50000 [==============================] - 4s 70us/step - loss: 0.8855 - acc: 0.6938 - val_loss: 1.5007 - val_acc: 0.4923
# Epoch 17/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.8572 - acc: 0.7055 - val_loss: 1.5588 - val_acc: 0.4891
# Epoch 18/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.8229 - acc: 0.7173 - val_loss: 1.5456 - val_acc: 0.4976
# Epoch 19/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 0.7915 - acc: 0.7291 - val_loss: 1.6523 - val_acc: 0.4753
# Epoch 20/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.7644 - acc: 0.7385 - val_loss: 1.7245 - val_acc: 0.4498
# Epoch 21/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.7313 - acc: 0.7508 - val_loss: 1.6285 - val_acc: 0.4795
# Epoch 22/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.7001 - acc: 0.7620 - val_loss: 1.7947 - val_acc: 0.4643
# Epoch 23/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.6802 - acc: 0.7697 - val_loss: 1.6308 - val_acc: 0.4780
# Epoch 24/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.6517 - acc: 0.7784 - val_loss: 1.6816 - val_acc: 0.4866
# Epoch 25/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.6184 - acc: 0.7937 - val_loss: 1.6546 - val_acc: 0.4910
# Epoch 26/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.5914 - acc: 0.8023 - val_loss: 1.7482 - val_acc: 0.4725
# Epoch 27/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.5631 - acc: 0.8130 - val_loss: 1.8197 - val_acc: 0.4706
# Epoch 28/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.5428 - acc: 0.8190 - val_loss: 1.7651 - val_acc: 0.4863
# Epoch 29/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.5217 - acc: 0.8276 - val_loss: 1.9763 - val_acc: 0.4602
# Epoch 30/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.4884 - acc: 0.8390 - val_loss: 1.8373 - val_acc: 0.4771
# Epoch 31/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.4578 - acc: 0.8528 - val_loss: 1.8233 - val_acc: 0.4804
# Epoch 32/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.4473 - acc: 0.8549 - val_loss: 1.9044 - val_acc: 0.4785
# Epoch 33/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.4268 - acc: 0.8620 - val_loss: 1.9461 - val_acc: 0.4679
# Epoch 34/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4069 - acc: 0.8689 - val_loss: 1.9404 - val_acc: 0.4674
# Epoch 35/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.3789 - acc: 0.8811 - val_loss: 2.0647 - val_acc: 0.4645
# Epoch 36/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.3593 - acc: 0.8878 - val_loss: 1.9630 - val_acc: 0.4856
# Epoch 37/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.3449 - acc: 0.8931 - val_loss: 2.0552 - val_acc: 0.4724
# Epoch 38/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.3265 - acc: 0.8994 - val_loss: 1.9766 - val_acc: 0.4738
# Epoch 39/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.3033 - acc: 0.9078 - val_loss: 2.2089 - val_acc: 0.4584
# Epoch 40/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 0.2953 - acc: 0.9098 - val_loss: 2.1509 - val_acc: 0.4717
# Epoch 41/50
# 50000/50000 [==============================] - 4s 71us/step - loss: 0.2850 - acc: 0.9122 - val_loss: 2.2204 - val_acc: 0.4689
# Epoch 42/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.2684 - acc: 0.9207 - val_loss: 2.1781 - val_acc: 0.4656
# Epoch 43/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.2550 - acc: 0.9237 - val_loss: 2.2727 - val_acc: 0.4753
# Epoch 44/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.2347 - acc: 0.9331 - val_loss: 2.1673 - val_acc: 0.4852
# Epoch 45/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.2225 - acc: 0.9375 - val_loss: 2.3047 - val_acc: 0.4709
# Epoch 46/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.2129 - acc: 0.9396 - val_loss: 2.2604 - val_acc: 0.4770
# Epoch 47/50
# 50000/50000 [==============================] - 4s 72us/step - loss: 0.2064 - acc: 0.9412 - val_loss: 2.3628 - val_acc: 0.4588
# Epoch 48/50
# 50000/50000 [==============================] - 4s 70us/step - loss: 0.1931 - acc: 0.9466 - val_loss: 2.3866 - val_acc: 0.4682
# Epoch 49/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.1854 - acc: 0.9477 - val_loss: 2.4692 - val_acc: 0.4668
# Epoch 50/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.1757 - acc: 0.9518 - val_loss: 2.4736 - val_acc: 0.4722
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 1.9768 - acc: 0.3318 - val_loss: 1.9378 - val_acc: 0.3516
# Epoch 2/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.6164 - acc: 0.4342 - val_loss: 1.6943 - val_acc: 0.4069
# Epoch 3/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.5113 - acc: 0.4703 - val_loss: 1.6230 - val_acc: 0.4321
# Epoch 4/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4356 - acc: 0.4963 - val_loss: 1.5366 - val_acc: 0.4596
# Epoch 5/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.3771 - acc: 0.5180 - val_loss: 1.5259 - val_acc: 0.4597
# Epoch 6/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.3278 - acc: 0.5352 - val_loss: 1.5192 - val_acc: 0.4624
# Epoch 7/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.2865 - acc: 0.5486 - val_loss: 1.4894 - val_acc: 0.4700
# Epoch 8/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.2469 - acc: 0.5629 - val_loss: 1.4659 - val_acc: 0.4808
# Epoch 9/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.2086 - acc: 0.5795 - val_loss: 1.4747 - val_acc: 0.4802
# Epoch 10/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.1740 - acc: 0.5928 - val_loss: 1.4770 - val_acc: 0.4774
# Epoch 11/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.1401 - acc: 0.6028 - val_loss: 1.4583 - val_acc: 0.4838
# Epoch 12/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.1080 - acc: 0.6150 - val_loss: 1.4689 - val_acc: 0.4848
# Epoch 13/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.0747 - acc: 0.6294 - val_loss: 1.4683 - val_acc: 0.4907
# Epoch 14/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.0408 - acc: 0.6402 - val_loss: 1.4518 - val_acc: 0.4906
# Epoch 15/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.0123 - acc: 0.6538 - val_loss: 1.5084 - val_acc: 0.4791
# Epoch 16/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.9829 - acc: 0.6638 - val_loss: 1.4661 - val_acc: 0.4916
# Epoch 17/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.9514 - acc: 0.6742 - val_loss: 1.4553 - val_acc: 0.5000
# Epoch 18/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.9252 - acc: 0.6836 - val_loss: 1.4725 - val_acc: 0.4948
# Epoch 19/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.8984 - acc: 0.6944 - val_loss: 1.5008 - val_acc: 0.4930
# Epoch 20/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.8683 - acc: 0.7051 - val_loss: 1.5006 - val_acc: 0.4924
# Epoch 21/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.8400 - acc: 0.7168 - val_loss: 1.4868 - val_acc: 0.4977
# Epoch 22/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.8113 - acc: 0.7263 - val_loss: 1.4927 - val_acc: 0.4961
# Epoch 23/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.7856 - acc: 0.7374 - val_loss: 1.5447 - val_acc: 0.4852
# Epoch 24/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.7578 - acc: 0.7478 - val_loss: 1.5175 - val_acc: 0.4949
# Epoch 25/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.7343 - acc: 0.7585 - val_loss: 1.5534 - val_acc: 0.4966
# Epoch 26/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.7065 - acc: 0.7681 - val_loss: 1.5962 - val_acc: 0.4810
# Epoch 27/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.6801 - acc: 0.7800 - val_loss: 1.6056 - val_acc: 0.4826
# Epoch 28/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.6571 - acc: 0.7851 - val_loss: 1.5838 - val_acc: 0.4935
# Epoch 29/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.6322 - acc: 0.7967 - val_loss: 1.6131 - val_acc: 0.4886
# Epoch 30/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.6056 - acc: 0.8085 - val_loss: 1.6228 - val_acc: 0.4888
# Epoch 31/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.5788 - acc: 0.8186 - val_loss: 1.6427 - val_acc: 0.4829
# Epoch 32/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5605 - acc: 0.8240 - val_loss: 1.6684 - val_acc: 0.4834
# Epoch 33/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5344 - acc: 0.8341 - val_loss: 1.7091 - val_acc: 0.4812
# Epoch 34/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.5100 - acc: 0.8434 - val_loss: 1.6796 - val_acc: 0.4911
# Epoch 35/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.4882 - acc: 0.8521 - val_loss: 1.7157 - val_acc: 0.4857
# Epoch 36/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.4668 - acc: 0.8610 - val_loss: 1.6952 - val_acc: 0.4891
# Epoch 37/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.4461 - acc: 0.8682 - val_loss: 1.7278 - val_acc: 0.4897
# Epoch 38/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.4218 - acc: 0.8768 - val_loss: 1.7891 - val_acc: 0.4814
# Epoch 39/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.4038 - acc: 0.8850 - val_loss: 1.8540 - val_acc: 0.4833
# Epoch 40/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.3811 - acc: 0.8925 - val_loss: 1.8091 - val_acc: 0.4899
# Epoch 41/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.3613 - acc: 0.9014 - val_loss: 1.8823 - val_acc: 0.4876
# Epoch 42/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.3447 - acc: 0.9073 - val_loss: 1.8641 - val_acc: 0.4934
# Epoch 43/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.3266 - acc: 0.9135 - val_loss: 1.9142 - val_acc: 0.4807
# Epoch 44/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.3131 - acc: 0.9184 - val_loss: 1.9102 - val_acc: 0.4849
# Epoch 45/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.2947 - acc: 0.9260 - val_loss: 1.9621 - val_acc: 0.4893
# Epoch 46/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.2782 - acc: 0.9305 - val_loss: 1.9287 - val_acc: 0.4952
# Epoch 47/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.2612 - acc: 0.9370 - val_loss: 1.9681 - val_acc: 0.4872
# Epoch 48/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.2456 - acc: 0.9430 - val_loss: 1.9943 - val_acc: 0.4826
# Epoch 49/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.2313 - acc: 0.9481 - val_loss: 1.9856 - val_acc: 0.4857
# Epoch 50/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.2196 - acc: 0.9518 - val_loss: 2.0789 - val_acc: 0.4825

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""

color = ['r','g','b']
plt.figure(figsize=(8,6))

for i,key in enumerate(results.keys()):
    plt.plot(range(len(results[key]['train_loss'])),results[key]['train_loss'],label = "train_loss" + key,color=color[i])
    plt.plot(range(len(results[key]['valid_loss'])),results[key]['valid_loss'],label = "val_loss" + key,color=color[i])
plt.legend()
plt.title("Loss")
plt.show()

for i,key in enumerate(results.keys()):
    plt.plot(range(len(results[key]['train_acc'])),results[key]['train_acc'],label = "train_acc" + key,color=color[i])
    plt.plot(range(len(results[key]['valid_acc'])),results[key]['valid_acc'],label = "val_acc" + key,color=color[i])
plt.legend()
plt.title("ACUURACY")
plt.show()
